# %%
import numpy as np
num_points = 100
x_data = []
y_data = []
for i in range(num_points):
    x1 = np.random.normal(0.0,0.55)
    y1 = x1 * 0.1 + 0.3 + np.random.normal(0.0,0.03)
    x_data.append(x1)
    y_data.append(y1)

# %%
import matplotlib.pyplot as plt

plt.plot(x_data,y_data,'ro',label='Original data')
plt.legend()
plt.show()

# %%
import tensorflow as tf

W = tf.Variable(tf.random_uniform([1],-1.0,1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y-y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)
for step in range(40):
    sess.run(train)
    print(step,sess.run(W),sess.run(b))
    print(step,sess.run(loss))

    plt.plot(x_data,y_data,'ro',label = 'Original_data')
    plt.plot(x_data,sess.run(W) * x_data + sess.run(b),'y-',label = 'Train_data')
    plt.xlabel('x')
    plt.xlim(-2,2)
    plt.ylim(0.1,0.6)
    plt.ylabel('y')
    plt.legend()
    plt.show()
# Out:
# 0 [ 0.00915037] [ 0.29737562]
# 0 0.00270104
# 1 [ 0.02995684] [ 0.29777643]
# 1 0.00194734
# 2 [ 0.04535905] [ 0.29819107]
# 2 0.00153417
# 3 [ 0.05676306] [ 0.298498]
# 3 0.00130766
# 4 [ 0.06520674] [ 0.29872528]
# 4 0.00118349
# 5 [ 0.07145856] [ 0.29889354]
# 5 0.00111541
# 6 [ 0.07608748] [ 0.29901811]
# 6 0.00107809
# 7 [ 0.0795148] [ 0.29911035]
# 7 0.00105763
# 8 [ 0.08205243] [ 0.29917866]
# 8 0.00104642
# 9 [ 0.08393133] [ 0.29922923]
# 9 0.00104027
# 10 [ 0.08532248] [ 0.29926667]
# 10 0.0010369
# 11 [ 0.08635252] [ 0.29929441]
# 11 0.00103505
# 12 [ 0.08711517] [ 0.29931492]
# 12 0.00103404
# 13 [ 0.08767985] [ 0.29933012]
# 13 0.00103348
# 14 [ 0.08809794] [ 0.29934138]
# 14 0.00103318
# 15 [ 0.08840751] [ 0.2993497]
# 15 0.00103301
# 16 [ 0.08863671] [ 0.29935586]
# 16 0.00103292
# 17 [ 0.08880642] [ 0.29936045]
# 17 0.00103287
# 18 [ 0.08893207] [ 0.29936382]
# 18 0.00103284
# 19 [ 0.08902511] [ 0.29936633]
# 19 0.00103283
# 20 [ 0.08909399] [ 0.29936817]
# 20 0.00103282
# 21 [ 0.089145] [ 0.29936954]
# 21 0.00103282
# 22 [ 0.08918276] [ 0.29937059]
# 22 0.00103281
# 23 [ 0.08921072] [ 0.29937133]
# 23 0.00103281
# 24 [ 0.08923142] [ 0.2993719]
# 24 0.00103281
# 25 [ 0.08924675] [ 0.29937229]
# 25 0.00103281
# 26 [ 0.0892581] [ 0.29937261]
# 26 0.00103281
# 27 [ 0.0892665] [ 0.29937282]
# 27 0.00103281
# 28 [ 0.08927272] [ 0.299373]
# 28 0.00103281
# 29 [ 0.08927733] [ 0.29937312]
# 29 0.00103281
# 30 [ 0.08928074] [ 0.29937321]
# 30 0.00103281
# 31 [ 0.08928327] [ 0.29937327]
# 31 0.00103281
# 32 [ 0.08928514] [ 0.29937333]
# 32 0.00103281
# 33 [ 0.08928652] [ 0.29937336]
# 33 0.00103281
# 34 [ 0.08928754] [ 0.29937339]
# 34 0.00103281
# 35 [ 0.0892883] [ 0.29937342]
# 35 0.00103281
# 36 [ 0.08928886] [ 0.29937342]
# 36 0.00103281
# 37 [ 0.08928928] [ 0.29937345]
# 37 0.00103281
# 38 [ 0.08928958] [ 0.29937345]
# 38 0.00103281
# 39 [ 0.08928981] [ 0.29937345]
# 39 0.00103281
